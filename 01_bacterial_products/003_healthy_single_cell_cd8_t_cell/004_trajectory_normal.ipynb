# %% [markdown]
# ## 1 · Imports

# %%
from anndata import AnnData
from typing import Optional

# Libraries
import anndata as ad
import matplotlib as plt
import numpy as np
import pandas as pd
import scanpy as sc
from matplotlib.pyplot import rc_context
from scipy.stats import median_abs_deviation

from functools import partial
import altair as alt
import seaborn as sns
import decoupler as dc
from scipy.sparse import csr_matrix
import os
from pathlib import Path

import mudata as mu
import scanpy as sc
import scirpy as ir
import altair as alt
alt.data_transformers.enable("vegafusion")

import anndata as ad
import numpy as np
import palantir

import numpy as np
import scipy.sparse as sp

# %%
import muon as mu
from muon import MuData

# %% [markdown]
# ## 2 · Data Loading
#
# Load mudata

# %%
mdata = mu.read_h5mu("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/40_gex_surface_prot/002_annotate_mudata_normal.h5mu")

# %%
mdata

# %%
sc.pl.umap(mdata["gex"], color=["cell_annotation_05", "condition", "sample_id"])

# %% [markdown]
# ## 3 · PAGA

# %%
sc.tl.draw_graph(mdata["gex"])

# %%
sc.pl.draw_graph(mdata["gex"], color="cell_annotation_05", legend_loc="on data")

# %%
sc.tl.paga(mdata["gex"], groups="cell_annotation_05")

# %%
sc.pl.paga(mdata["gex"], color=["cell_annotation_05"])

# %%
mdata.update()

# %%
mdata

# %% [markdown]
# ## 3 · Pseudotime

# %%
root_celltype = "Naive"

#sc.pp.neighbors(mdata["gex"], use_rep="X_pca")
#sc.tl.diffmap(mdata["gex"])
#sc.pp.neighbors(mdata["gex"], use_rep="X_diffmap")

iroot = np.flatnonzero(mdata["gex"].obs["cell_annotation_05"] == root_celltype)[0]
mdata["gex"].uns["iroot"] = iroot
sc.tl.dpt(mdata["gex"])

# %%
sc.pl.paga(mdata["gex"], color=["cell_annotation_05"])
sc.pl.umap(mdata["gex"], color=["cell_annotation_05", "dpt_pseudotime"], legend_loc="on data", cmap = "viridis", vmax="p99")

# %%
mdata.update()

# %%
mdata

# %%
mdata.write_h5mu("/data/projects/2021/MicrobialMetabolites/single-cell-sorted-cd8/results/40_gex_surface_prot/003_trajectory_annotated_mudata_normal.h5mu")
